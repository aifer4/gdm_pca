# %% [markdown]
# # PCA
# This notebook can be used to do PCA on the following things:
# - Sound speed and equation of state of the dark sector in the 2-fluid model
# - Sound speed and equation of state of dark matter and neutrinos in the 3-fluid model
# - Standard cosmological parameters in the 3-fluid model

# %%
# third party imports
import numpy as np
from numpy import exp, log, log10, sqrt, zeros, ones, linspace
import matplotlib.pyplot as plt
import numba
import pickle
from scipy.interpolate import CubicSpline

# other project files
import modes
import spectra
import util

# %%
# numerical parameters
NT = 2**13
NK = 2**11
NX = 10000
L_MAX = 2500
xmin = 0.01
xmax = 3000
a0 = 1.e-6
a0_pca = 5.e-5
a_rec = 1/1100

# arrays
A = np.linspace(a0, a_rec, 2*NT)
K = np.linspace(.1, 800, NK)
L = np.array([i for i in range(2, 50, 1)]+[i for i in range(50, 200, 5)] +
                  [i for i in range(200, L_MAX+1, 20)])
L_eval = np.arange(2, L_MAX+1)
NL = len(L)
X = np.linspace(xmin, xmax, NX)
JLX, DJLX = spectra.get_bessels(L, X)
# Out:
# Bessel functions loaded from file.

# %% [markdown]
# # 3-fluid  model
# The function params_PCA below gets the fisher matrix for the scalar-valued parameters in the 3-fluid model. Equation of state and sound speed for CDM and neutrinos are treated as scalar parameters (they aren't allowed to depend on time or wavenumber).

# %%
# physical parameters
h = 0.6774
As = np.exp(3.064)/1.e10 # scalar perturbation amplitude
TCMB0 = 2.72548 * 1.e6 # CMB temp (microK)
OmegaM0 = 0.3089
OmegaB0 = 0.0486
OmegaR0 = 4.2e-5/h**2
OmegaN0 = OmegaR0*(1-1/1.68)
OmegaG0 = OmegaR0 - OmegaN0
OmegaC0 = OmegaM0 - OmegaB0
wC = np.zeros(2*NT)
wN = np.ones(2*NT)*1/3
cs2C = np.zeros((2*NT, NK))
cs2N = np.ones((2*NT, NK))*1/3
params_F = [wC, cs2C, wN, cs2N, OmegaB0, OmegaC0, OmegaG0, OmegaN0, As, TCMB0, h]

Cl = spectra.get_Cl_3fld(L, L_eval, X, JLX, DJLX, A, K, *params_F)
err = spectra.get_Cl_err(L_eval,Cl)
Sigma = np.diag(err**2)

def params_PCA(t):
    """Fisher matrix for density parameters, equation of state, sound speed."""

    NC = len(params_F) #number of parameters
    ss = 0.1**t #(derivative step size)
    B = np.eye(NC)
    J = np.zeros((len(L_eval), NC))

    print('computing derivatives (t='+str(t)+')')
    # take the central-difference derivatives with respect to each parameter
    for n in range(NC):
        params_fwd = params_F + ss*B[n]
        params_bwd = params_F - ss*B[n]
        Cl_fwd = spectra.get_Cl_3fld(L, L_eval, X, JLX, DJLX, A, K, *params_fwd)
        Cl_bwd = spectra.get_Cl_3fld(L, L_eval, X, JLX, DJLX, A, K, *params_bwd)
        J[:, n] = (Cl_fwd - Cl_bwd)/(2.*ss)
            
    # save the derivatives
    pickle.dump(J, open("output/params/J_t-"+str(t)+".p", "wb"))
    print('\n','derivatives saved (t='+str(t)+')')
    
    F = J.T@np.linalg.inv(Sigma)@J
    pickle.dump(F, open("output/params/F_t-"+str(t)+".p", "wb"))
    print('\n','Fisher matrix saved (t='+str(t)+')')
    
#params_PCA(7)

# %% [markdown]
# #  2-fluid model
# Below are functions to do PCA on the equation of state and the sound speed of the dark sector in the two fluid model

# %%
"""Get the fiduciary parameters for the 2-fluid model"""

# solve for perturbation history using 3-fluid model.
Y, TAU = modes.solve_3fld(A, K, wC, cs2C, wN, cs2N, OmegaB0, OmegaC0,
           OmegaG0, OmegaN0)

Phi = Y[:, 0, :].T
deltaG = Y[:, 1, :].T
vG = Y[:, 2, :].T
deltaC =Y[:, 3, :].T
vC = Y[:, 4, :].T
deltaN = Y[:, 5, :].T
vN =Y[:, 6, :].T

OmegaB = OmegaB0 * A[::2]**-3
OmegaC = OmegaC0 * A[::2]**-3
OmegaN = OmegaN0 * A[::2]**-4
OmegaG = OmegaG0 * A[::2]**-4
OmegaD = OmegaN + OmegaC

# calculate GDM functions
wD = OmegaN/(3*OmegaD)
deltaD = (OmegaC*deltaC + OmegaN*deltaN)/OmegaD
vD = (OmegaC*vC + 4/3*OmegaN*vN)/((1+wD)*OmegaD)
cs2D = (deltaN*OmegaN/3)/(deltaD*OmegaD)
delta_pD = deltaN

deltaD, vD, cs2D, delta_pD = deltaD.T, vD.T, cs2D.T, delta_pD.T

Cl2 = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
plt.plot(Cl)
plt.plot(Cl2)

# %%
"""Helper functions for cs2 PCA"""

@numba.njit
def square_basis(theta, NC):
    height = NT//NC
    width = NK//NC
    out = np.zeros((NK, NT))
    for i in range(NC**2):
        r,c = i//NC, i%NC
        out[r*width:(r+1)*width, c*height:(c+1)*height] = theta[i]
    out[:,A[::2] < a0_pca]=0
    return out.T

def get_square(n, val, NC):
    height = NT//NC
    width = NK//NC
    out = np.zeros((NK, NT))
    r,c = n//NC, n%NC
    out[r*width:(r+1)*width, c*height:(c+1)*height] = val
    out[:,A[::2] < a0_pca]=0
    return out.T

# %%
def W_PCA(q, t, a0):
    """This function does PCA on the equation of state in the 2-fluid model, with the sound speed fixed to the fiduciary.
    q determines the basis size, and t determines the derivative step size. a0 is the 'cutoff time', before
    which the equation of state is not varied during PCA. The outputs (derivatives, fisher matrix, PCs, and singular values)
    are saved to pickle files formatted like 'output/w-only/J_q-[q]_t-[t].p'. So, for example, if you make the function call
    W_PCA(q=7,t=7,a0=1.e-5), the following files will be created:
    output/w-only/J_q-7_t-5.p,  output/w-only/F_q-7_t-5.p,   output/w-only/PC_q-7_t-5.p,   output/w-only/SV_q-7_t-5.p.
    These respectively store the derivatives, the fisher matrix, the principal components, and the singular values.
    """
    
    NC = 2**q # number of basis elements
    ss = 0.1**t # derivative step size
    
    # initialize a 1-d gaussian basis
    B = np.zeros((NC,NT))
    width=NT//(NC-1)
    for i in range(NC):
        # each row of B is a gaussian basis-element
        if A[::2][i*width]>a0_pca:
            B[i] = np.exp(-(np.arange(NT) - i*width)**2 / (width)**2)
       
        #B[i,A[::2] < a0_pca]=0
    # initialize an empty array to hold the partial derivatives
    J = np.zeros((len(L_eval), NC))
    print('computing derivatives (q='+str(q)+',t='+str(t)+')')
    for n in range(NC):
        # Take the central-difference derivative of Cl with respect to the nth basis coefficient.
        Delta_w = ss*B[n]
        Cl_fwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD+Delta_w, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        Cl_bwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD-Delta_w, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        # The result goes in the nth column of J.
        J[:, n] = (Cl_fwd - Cl_bwd)/(2.*ss)
    
    # save the derivatives
    pickle.dump(J, open("output/w-only/J_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','derivatives saved (q='+str(q)+',t='+str(t)+')')
    
    # compute and save the  Fisher matrix.
    F = J.T@np.linalg.inv(Sigma)@J
    pickle.dump(F, open("output/w-only/F_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','Fisher matrix saved (q='+str(q)+',t='+str(t)+')')
    
    # compute and save the singular values and principal components.
    u, s, v = np.linalg.svd(F)
    PV = np.real(u) 
    PC = np.zeros((10, NT))
    for i in range(10):
        PC[i,:] = PV[:,i]@B
    pickle.dump(PC, open("output/w-only/PC_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    pickle.dump(s, open("output/w-only/SV_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','PCs and SVs saved (q='+str(q)+',t='+str(t)+')')

# %%
@numba.njit(parallel=True)
def W_PCA_interp(q, s, t, a0):
    """W PCA with interpolation
    - q (int) density parameter.
    - s (int): sharpness parameter.
    """
    
    NC = 2**q # number of basis elements
    width = NT//2**(q+s)
    ss = 0.1**t # derivative step size
    
    # initialize a 1-d gaussian basis
    B = np.zeros((NC,NT))
    # array to hold gaussian peak locations
    peaks = np.zeros(NC)
    spacing = NT//NC
    for i in range(NC):
        peaks[i] = int(i*spacing)
        # each row of B is a gaussian basis-element
        if A[::2][i*spacing]>a0_pca:
            B[i] = (width * sqrt(2*np.pi))**-1 * np.exp(
                -.5*(np.arange(NT) - i*spacing)**2 / (width)**2
            )

    # initialize an empty array to hold the partial derivatives
    J = np.zeros((len(L_eval), NC))
    print('computing derivatives')
    for n in range(NC):
        # Take the central-difference derivative of Cl with respect to the nth basis coefficient.
        Delta_w = ss*B[n]
        Cl_fwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD+Delta_w, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        Cl_bwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD-Delta_w, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        # The result goes in the nth column of J.
        J[:, n] = (Cl_fwd - Cl_bwd)/(2.*ss)
    print('computing eigenfunctions')
    # compute and save the singular values and principal components.
    SV, PV, err = util.Powit(J,np.diag(1/Sigma),10,np.random.rand(NC,10))
    PC = np.zeros((10, NT))
    for i in range(10):
        PC[i,:] = PV[:,i]@B
        
    #pickle.dump(PC, open("output/w-only/PC_interp.p", "wb"))
    #pickle.dump(SV, open("output/w-only/SV_interp.p", "wb"))
    print('\n','PCs and SVs saved')
    
    return SV, PC, peaks

# %%
PC= np.zeros((7, 10, NT))
PC_terp = np.zeros((7, 10, NT))
SV = np.zeros((7,10))

for i in range(7):
    qi = 4+i
    SVi, PCi, peaks = W_PCA_interp(q=qi, s=2, t=7, a0=a0_pca)
    SV[i,:] = SVi
    # now interpolate between peaks for each PC:
    for n in range(5):
        cs = CubicSpline(A[::2][peaks.astype(int)], PCi[n][peaks.astype(int)])
        PC_terp[i, n, :] = cs(A[::2])
        PC[i, n, :] = PCi[n]
        print('q: ', str(qi),' done. n =',str(n),'\n')
pickle.dump(PC, open("output/w-only/PC_spikes.p", "wb"))
pickle.dump(PC_terp, open("output/w-only/PC_terp.p", "wb"))
pickle.dump(SV, open("output/w-only/SV_spikes.p", "wb"))
# Out:
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  4  done. n = 0
#
# q:  4  done. n = 1
#
# q:  4  done. n = 2
#
# q:  4  done. n = 3
#
# q:  4  done. n = 4
#
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  5  done. n = 0
#
# q:  5  done. n = 1
#
# q:  5  done. n = 2
#
# q:  5  done. n = 3
#
# q:  5  done. n = 4
#
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  6  done. n = 0
#
# q:  6  done. n = 1
#
# q:  6  done. n = 2
#
# q:  6  done. n = 3
#
# q:  6  done. n = 4
#
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  7  done. n = 0
#
# q:  7  done. n = 1
#
# q:  7  done. n = 2
#
# q:  7  done. n = 3
#
# q:  7  done. n = 4
#
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  8  done. n = 0
#
# q:  8  done. n = 1
#
# q:  8  done. n = 2
#
# q:  8  done. n = 3
#
# q:  8  done. n = 4
#
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  9  done. n = 0
#
# q:  9  done. n = 1
#
# q:  9  done. n = 2
#
# q:  9  done. n = 3
#
# q:  9  done. n = 4
#
# computing derivatives
# computing eigenfunctions
#
#  PCs and SVs saved
# q:  10  done. n = 0
#
# q:  10  done. n = 1
#
# q:  10  done. n = 2
#
# q:  10  done. n = 3
#
# q:  10  done. n = 4

# %%
print(np.shape(PC))
# load PCs and SVs
PC = pickle.load(open("output/w-only/PC_spikes.p", "rb"))
PC_terp = pickle.load(open("output/w-only/PC_terp.p", "rb"))
SV = pickle.load(open("output/w-only/SV_spikes.p", "rb"))

# flip PCs:
for i in range(7):
    for n in range(5):
        PC[i,n,:]*=np.sign(np.sum(PC[i,n,:]))
        PC_terp[i,n,:]*=np.sign(np.sum(PC[i,n,:]))

def RRMSR(x1,x2):
    # relative root mean square error
    rmse = np.sqrt(np.mean((x2-x1)**2))
    rms2 = np.sqrt(np.mean(x2**2))
    return rmse/rms2

err = np.zeros((6,5))
for i in range(6):
    for n in range(5):
        err[i,n] = RRMSR(
            PC_terp[i, n, :]/sqrt(SV[i, n]),
            PC_terp[i+1, n, :]/sqrt(SV[i+1,n]))
        
plt.plot(err)
plt.semilogy()
# Out:
# (7, 5, 8192)
# []

# %%
fig, ax = plt.subplots(5,1,figsize=(20,20))

for n in range(5):
    for i in range(6):
        ax[n].plot(A[::2],PC_terp[i,n,:]/sqrt(SV[i,0]))
        #plt.axvline(a_eq,color = 'black',linestyle='--')
        plt.axvline(a_rec,color = 'red',linestyle='--')
        plt.axvline(.00005,color = 'green',linestyle=':',linewidth=3)
        plt.axhline(0,color='gray',linestyle=':')
        plt.xlabel('scale factor')
    if n==0:
        leg =['16 components','32 components','64 components','128 components','256 components',
              '512 components', '1024 components','equality', 'recombination', 'cutoff time']
        plt.legend(leg, loc=1)

# %%
np.shape(PC)
plt.plot(A[::2], PC[1,3,:])

# %%
def CS2_PCA(q, t, a0):
    """This function does PCA on the sound speed in the 2-fluid model, with the equation of state fixed to the fiduciary.
    q determines the basis size, and t determines the derivative step size. a0 is the 'cutoff time', before
    which the sound speed is not varied during PCA. The outputs (derivatives, fisher matrix, PCs, and singular values)
    are saved to pickle files formatted like 'output/cs2-only/J_q-[q]_t-[t].p'. So, for example, if you make the function call
    W_PCA(q=7,t=7,a0=1.e-5), the following files will be created:
    output/cs2-only/J_q-7_t-5.p,  output/cs2-only/F_q-7_t-5.p,   output/cs2-only/PC_q-7_t-5.p,   output/cs2-only/SV_q-7_t-5.p.
    These respectively store the derivatives, the fisher matrix, the principal components, and the singular values.
    """
    NC = 2**q # number of basis elements
    ss = 0.1**t # derivative step size
    
    # take the central-difference derivatives of Cl w.r.t. cs2 basis coefficients.
    J = np.zeros((len(L_eval), NC**2))
    print('computing derivatives (t='+str(t)+')')
    for n in range(NC**2):
        delta_cs2 = get_square(n, ss, NC)
        Cl_fwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD, cs2D+delta_cs2,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        Cl_bwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD, cs2D-delta_cs2,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        J[:, n] = (Cl_fwd - Cl_bwd)/(2.*ss)
        if(n % 10 == 0):
            print(str(n) + ' of ' + str(NC**2))
    
    # save the derivatives
    pickle.dump(J, open("output/cs2-only/J_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','derivatives saved (q='+str(q)+',t='+str(t)+')')
    
    # compute and save the  Fisher matrix.
    F = J.T@np.linalg.inv(Sigma)@J
    pickle.dump(F, open("output/cs2-only/F_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','Fisher matrix saved (q='+str(q)+',t='+str(t)+')')
    
    print('\n','computing PCs (t='+str(t)+')')
    u, s, v = np.linalg.svd(F)
    PV = np.real(u) 
    PC = np.zeros((10, NT, NK))
    for i in range(10):
        PC[i,:,:] = square_basis(PV[:,i], NC)
    pickle.dump(PC, open("output/cs2-only/PC_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    pickle.dump(s, open("output/cs2-only/SV_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','PCs and SVs saved (q='+str(q)+',t='+str(t)+')')

# %%
def W_CS2_PCA(q, t, a0):
    NC = 2**q # number of basis elements
    ss = 0.1**t # derivative step size

    # initialize a 1-d gaussian basis
    B = np.zeros((NC,NT))
    width=NT//(NC-1)
    for i in range(NC):
        # each row of B is a gaussian basis-element
        if A[::2][i*width]>a0_pca:
            B[i] = np.exp(-(np.arange(NT) - i*width)**2 / (width)**2)

    J_w = pickle.load(open("output/w-only/J_q-"+str(q)+"_t-"+str(t)+".p", "rb"))
    J_cs2 = pickle.load(open("output/cs2-only/J_q-"+str(q)+"_t-"+str(t)+".p", "rb"))
    J = np.concatenate((J_w,J_cs2),axis=1)

    print('\n','computing PCs (t='+str(t)+')')
    
    v_init = np.random.rand(NC**2+NC,10)
    
    s, PV, err = util.Powit(J,1/np.diag(Sigma),10,v_init)

    PV_w = PV[:NC,:]
    PV_cs2 = PV[NC:,:]
    print(np.shape(PV_w))

    PC_w = np.zeros((10, NT))
    PC_cs2 = np.zeros((10, NT, NK))
    for i in range(10):
        PC_w[i,:] = PV_w[:,i]@B
        PC_cs2[i,:,:] = square_basis(PV_cs2[:,i], NC)
    pickle.dump(PC_w, open("output/w-cs2/wPC_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    pickle.dump(PC_cs2, open("output/w-cs2/cs2PC_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    pickle.dump(s, open("output/w-cs2/SV_q-"+str(q)+"_t-"+str(t)+".p", "wb"))
    print('\n','PCs and SVs saved (q='+str(q)+',t='+str(t)+')')

# %%
# rescaled w pca
def W_PCA_rescaled(q, t, a0, F_diag):

    NC = 2**q # number of basis elements
    ss = 0.1**t # derivative step size
    
    # initialize a 1-d gaussian basis
    B = np.zeros((NC,NT))
    width=NT//(NC-1)
    for i in range(NC):
        # each row of B is a gaussian basis-element
        if A[::2][i*width]>a0_pca:
            B[i] = np.exp(-(np.arange(NT) - i*width)**2 / (width)**2) 
            B[i] /= sqrt(F_diag[i]) #rescale the basis function
       
        #B[i,A[::2] < a0_pca]=0
    # initialize an empty array to hold the partial derivatives
    J = np.zeros((len(L_eval), NC))
    print('computing derivatives (q='+str(q)+',t='+str(t)+')')
    for n in range(NC):
        # Take the central-difference derivative of Cl with respect to the nth basis coefficient.
        Delta_w = ss*B[n]
        Cl_fwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD+Delta_w, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        Cl_bwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD-Delta_w, cs2D,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        # The result goes in the nth column of J.
        J[:, n] = (Cl_fwd - Cl_bwd)/(2.*ss)
    
    # save the derivatives
    pickle.dump(J, open("output/w-only/J_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    print('\n','derivatives saved (q='+str(q)+',t='+str(t)+')')
    
    # compute and save the  Fisher matrix.
    F = J.T@np.linalg.inv(Sigma)@J
    pickle.dump(F, open("output/w-only/F_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    print('\n','Fisher matrix saved (q='+str(q)+',t='+str(t)+')')
    
    # compute and save the singular values and principal components.
    u, s, v = np.linalg.svd(F)
    PV = np.real(u) 
    PC = np.zeros((10, NT))
    for i in range(10):
        PC[i,:] = PV[:,i]@B
    pickle.dump(PC, open("output/w-only/PC_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    pickle.dump(s, open("output/w-only/SV_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    print('\n','PCs and SVs saved (q='+str(q)+',t='+str(t)+')')

# %%
def CS2_PCA_rescaled(q, t, a0, F_diag):
    """This function does PCA on the sound speed in the 2-fluid model, with the equation of state fixed to the fiduciary.
    q determines the basis size, and t determines the derivative step size. a0 is the 'cutoff time', before
    which the sound speed is not varied during PCA. The outputs (derivatives, fisher matrix, PCs, and singular values)
    are saved to pickle files formatted like 'output/cs2-only/J_q-[q]_t-[t].p'. So, for example, if you make the function call
    W_PCA(q=7,t=7,a0=1.e-5), the following files will be created:
    output/cs2-only/J_q-7_t-5.p,  output/cs2-only/F_q-7_t-5.p,   output/cs2-only/PC_q-7_t-5.p,   output/cs2-only/SV_q-7_t-5.p.
    These respectively store the derivatives, the fisher matrix, the principal components, and the singular values.
    """
    NC = 2**q # number of basis elements
    ss = 0.1**t # derivative step size
    
    # take the central-difference derivatives of Cl w.r.t. cs2 basis coefficients.
    J = np.zeros((len(L_eval), NC**2))
    print('computing derivatives (t='+str(t)+')')
    for n in range(NC**2):
        delta_cs2 = get_square(n, ss, NC) / sqrt(F_diag[n])
        Cl_fwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD, cs2D+delta_cs2,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        Cl_bwd = spectra.get_Cl_2fld(L, L_eval, X, JLX, DJLX, A[::2], K, wD, cs2D-delta_cs2,
                                     deltaD[0], vD[0], OmegaB0, OmegaC0, OmegaG0, OmegaN0,
                                     As, TCMB0, h)
        J[:, n] = (Cl_fwd - Cl_bwd)/(2.*ss)
        if(n % 10 == 0):
            print(str(n) + ' of ' + str(NC**2))
    
    # save the derivatives
    pickle.dump(J, open("output/cs2-only/J_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    print('\n','derivatives saved (q='+str(q)+',t='+str(t)+')')
    
    # compute and save the  Fisher matrix.
    F = J.T@np.linalg.inv(Sigma)@J
    pickle.dump(F, open("output/cs2-only/F_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    print('\n','Fisher matrix saved (q='+str(q)+',t='+str(t)+')')
    
    print('\n','computing PCs (t='+str(t)+')')
    u, s, v = np.linalg.svd(F)
    PV = np.real(u) 
    PC = np.zeros((10, NT, NK))
    for i in range(10):
        PC[i,:,:] = square_basis(PV[:,i], NC)
    pickle.dump(PC, open("output/cs2-only/PC_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    pickle.dump(s, open("output/cs2-only/SV_q-"+str(q)+"_t-"+str(t)+"_rescaled.p", "wb"))
    print('\n','PCs and SVs saved (q='+str(q)+',t='+str(t)+')')

# %%
# load the w fisher matrix
F  = pickle.load(open("output/w-only/F_q-7_t-7.p", "rb"))
Fr = np.load("output/w-only/F_q-7_t-7_rescaled.p",allow_pickle=True)
plt.imshow(Fr)
plt.colorbar()
#plt.plot(np.diag(F))

# %%
F = np.load("output/w-only/F_q-7_t-7.p",allow_pickle=True)
Fr = np.load("output/w-only/F_q-7_t-7_rescaled.p",allow_pickle=True)
plt.plot(np.diag(F))
plt.plot(np.diag(Fr))
plt.title("Fisher matrix diagonal for normalized and rescaled bases")
plt.legend(['normalized basis', 'rescaled basis'])
plt.xlabel('i')
plt.ylabel('$F_{ii}$')
plt.semilogy()
# Out:
# []

# %%
"""Rescaled w PCA (takes a while)"""
#W_PCA_rescaled(q=4, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/w-only/F_q-4_t-7.p",allow_pickle=True)))
#W_PCA_rescaled(q=5, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/w-only/F_q-5_t-7.p",allow_pickle=True)))
#W_PCA_rescaled(q=6, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/w-only/F_q-6_t-7.p",allow_pickle=True)))
#W_PCA_rescaled(q=7, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/w-only/F_q-7_t-7.p",allow_pickle=True)))
#W_PCA_rescaled(q=8, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/w-only/F_q-8_t-7.p",allow_pickle=True))#)
# Out:
# 'Rescaled w PCA (takes a while)'

# %%
"""Rescaled w PCA (takes a while)"""
#CS2_PCA_rescaled(q=4, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/cs2-only/F_q-4_t-7.p",allow_pickle=True)))
#CS2_PCA_rescaled(q=5, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/cs2-only/F_q-5_t-7.p",allow_pickle=True)))
#CS2_PCA_rescaled(q=6, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/cs2-only/F_q-6_t-7.p",allow_pickle=True)))
#CS2_PCA_rescaled(q=7, t=7, a0=a0_pca, F_diag = np.diag(np.load("output/cs2-only/F_q-7_t-7.p",allow_pickle=True)))
# Out:
# 'Rescaled w PCA (takes a while)'

# %%
# this takes a long time...
W_PCA(q=4, t=7, a0=a0_pca)
W_PCA(q=5, t=7, a0=a0_pca)
W_PCA(q=6, t=7, a0=a0_pca)
W_PCA(q=7, t=7, a0=a0_pca)
CS2_PCA(q=4, t=7, a0=a0_pca)
CS2_PCA(q=5, t=7, a0=a0_pca)
CS2_PCA(q=6, t=7, a0=a0_pca)
CS2_PCA(q=7, t=7, a0=a0_pca)
W_CS2_PCA(q=4, t=7, a0=a0_pca)
W_CS2_PCA(q=5, t=7, a0=a0_pca)
W_CS2_PCA(q=6, t=7, a0=a0_pca)
W_CS2_PCA(q=7, t=7, a0=a0_pca)
# Out:
# computing derivatives (q=4,t=7)
#
#  derivatives saved (q=4,t=7)
#
#  Fisher matrix saved (q=4,t=7)
#
#  PCs and SVs saved (q=4,t=7)
# computing derivatives (q=5,t=7)
#
#  derivatives saved (q=5,t=7)
#
#  Fisher matrix saved (q=5,t=7)
#
#  PCs and SVs saved (q=5,t=7)
# computing derivatives (q=6,t=7)
#
#  derivatives saved (q=6,t=7)
#
#  Fisher matrix saved (q=6,t=7)
#
#  PCs and SVs saved (q=6,t=7)
# computing derivatives (q=7,t=7)
#
#  derivatives saved (q=7,t=7)
#
#  Fisher matrix saved (q=7,t=7)
#
#  PCs and SVs saved (q=7,t=7)
# computing derivatives (t=7)
# 0 of 16384
# 10 of 16384
# 20 of 16384
# 30 of 16384
# 40 of 16384
# 50 of 16384
# 60 of 16384
# 70 of 16384
# 80 of 16384
# 90 of 16384
# 100 of 16384
# 110 of 16384
# 120 of 16384
# 130 of 16384
# 140 of 16384
# 150 of 16384
# 160 of 16384
# 170 of 16384
# 180 of 16384
# 190 of 16384
# 200 of 16384
# 210 of 16384
# 220 of 16384
# 230 of 16384
# 240 of 16384
# 250 of 16384
# 260 of 16384
# 270 of 16384
# 280 of 16384
# 290 of 16384
# 300 of 16384
# 310 of 16384
# 320 of 16384
# 330 of 16384
# 340 of 16384
# 350 of 16384
# 360 of 16384
# 370 of 16384
# 380 of 16384
# 390 of 16384
# 400 of 16384
# 410 of 16384
# 420 of 16384
# 430 of 16384
# 440 of 16384
# 450 of 16384
# 460 of 16384
# 470 of 16384
# 480 of 16384
# 490 of 16384
# 500 of 16384
# 510 of 16384
# 520 of 16384
# 530 of 16384
# 540 of 16384
# 550 of 16384
# 560 of 16384
# 570 of 16384
# 580 of 16384
# 590 of 16384
# 600 of 16384
# 610 of 16384
# 620 of 16384
# 630 of 16384
# 640 of 16384
# 650 of 16384
# 660 of 16384
# 670 of 16384
# 680 of 16384
# 690 of 16384
# 700 of 16384
# 710 of 16384
# 720 of 16384
# 730 of 16384
# 740 of 16384
# 750 of 16384
# 760 of 16384
# 770 of 16384
# 780 of 16384
# 790 of 16384
# 800 of 16384
# 810 of 16384
# 820 of 16384
# 830 of 16384
# 840 of 16384
# 850 of 16384
# 860 of 16384
# 870 of 16384
# 880 of 16384
# 890 of 16384
# 900 of 16384
# 910 of 16384
# 920 of 16384
# 930 of 16384
# 940 of 16384
# 950 of 16384
# 960 of 16384
# 970 of 16384
# 980 of 16384
# 990 of 16384
