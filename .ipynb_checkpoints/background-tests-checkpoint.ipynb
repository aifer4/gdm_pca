# %%
import numpy as np
import modes
import util
from util import trapz, backtrapz, deriv
from matplotlib import pyplot as plt

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
# numerical params
NT = 1000
NK = 500
a0 = 1.e-6

# %%
h = .8
OmegaM0 = .2
OmegaB0 = 0.03
OmegaR0 = 4.2e-5/h**2
OmegaN0 = OmegaR0*(1-1/1.68)
OmegaG0 = OmegaR0 - OmegaN0
OmegaC0 = OmegaM0 - OmegaB0

a_rec = 1/1100

a_eq = OmegaR0/OmegaM0

alpha = (a_rec/a_eq)**.5
x_rec = ((alpha**2 + 1)**.5 - 1)/alpha
tau_r = (OmegaM0/a_rec)**.5 * H0/2

X = np.linspace(0,x_rec, NT+1)[1:]
Y = (alpha*X)**2 + 2*alpha*X
eta = 2*alpha*(alpha*X+1)/(alpha**2*X**2+2*alpha*X)
yb = 1.68*Y*OmegaB0/OmegaM0

# get standard cosmological variables from seljak variables
A_sel = Y*a_eq
TAU_sel = X/tau_r
H_sel = eta*tau_r

# get standard variables the normal way
A = np.linspace(0, a_rec, NT+1)[1:]
OmegaM = OmegaM0*A**-3
OmegaR = OmegaR0*A**-4
OmegaB = OmegaB0*A**-3
OmegaG = OmegaG0*A**-4
H =  H0 * A * np.sqrt(OmegaM + OmegaR)
TAU = trapz(A, 1/(A * H))

# %%
plt.plot(A,TAU)
plt.plot(A_sel,TAU_sel, linestyle='--',color='black')
plt.show()

plt.plot(A_sel,yb)
plt.plot(A,OmegaB/OmegaG, linestyle='--',color='black')

# %%
A = np.linspace(a0, 1, NT)
A = np.geomspace(a0, 1, NT)
a_rec = 1/1100
H0 = 1.

#%matplotlib notebook
# Create two subplots and unpack the output array immediately
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

h = 0.5
OmegaB0 = 0.05
OmegaM0 = 1.0
a_eq = 4.2e-5/(OmegaM0 * h**2)
OmegaR0 = OmegaM0 * a_eq
wC = np.zeros(NT)
wN = np.ones(NT)*1/3

OmegaM = OmegaM0*A**-3
OmegaR = OmegaR0*A**-4
H =  H0 * A * np.sqrt(OmegaM + OmegaR) 

ax1.plot(A,H, color='xkcd:light gray',linestyle='--')
H_line, = ax1.plot(A,H)
a_eq_line = ax1.axvline(a_eq)
ax1.axvline(a_rec)
ax1.loglog()

OmegaM_line, = ax2.plot(A,OmegaM)
OmegaR_line, = ax2.plot(A,OmegaR)
a_eq_line2 = ax2.axvline(a_eq)
ax2.axvline(a_rec)
ax2.loglog()   
#fig.tight_layout()
#plt.show()


#or i in range(1,10):
@interact(h2=(0.1,2), mu=(1,NT), sig=(NT//100, NT//5))
def update_plot(h2, mu, sig):
    # create bump
    xb = np.arange(NT)
    bump = np.exp(-np.power(xb - mu, 2.) / (2 * np.power(sig, 2.)))
    
    h = h2**2
    OmegaB0 = 0.05
    OmegaM0 = 1.0
    OmegaC0 = OmegaM0 - OmegaB0
    OmegaN0 = 0
    a_eq = 4.2e-5/(OmegaM0 * h**2)
    OmegaR0 = OmegaM0 * a_eq
    OmegaG0 = OmegaR0 - OmegaN0
    
    wC = np.zeros(NT)+bump
    wN = np.ones(NT)*1/3

    OmegaM = OmegaM0*A**-3*np.exp(-3*backtrapz(A, wC/A))
    OmegaR = OmegaR0*A**-4*np.exp(-3*backtrapz(A,(wN-1/3)/A))
    H =  H0 * A * np.sqrt(OmegaM + OmegaR) 

    H_line.set_ydata(H)
    #H_line.set_ydata(bump)
    OmegaM_line.set_ydata(OmegaM)
    OmegaR_line.set_ydata(OmegaR)
    a_eq_line.set_xdata(a_eq)
    

    OmegaR_marker.set_ydata(OmegaR0)
    a_eq_line2.set_xdata(a_eq)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=1.05, description='h2', max=2.0, min=0.1), IntSlider(value=50, descrip…

# %%
TAU = trapz(A, 1/(A * H))
plt.plot(A,TAU)
plt.plot(A_sel, TAU_sel,linestyle=':',color='black',linewidth=2)
plt.show()

# %%
#@numba.njit
def DY_3fld(i, Y, A, K, wC, DwC, cs2C, wN, DwN, cs2N,
            OmegaC, OmegaN, OmegaB0, OmegaC0, OmegaG0, OmegaN0, H):
    """
    Mode evolution for 3-fluid (Seljak's 2-fluid + neutrinos) model.
    
    """
    dY = np.zeros((7, len(K)))
    [Phi, deltaG, vG, deltaC, vC, deltaN, vN] = Y
    
    ybi = 1.68*A[i]*OmegaB0/(OmegaN0 + OmegaG0)
  
    OmegaBi = OmegaB0 * A[i]**-3.
    OmegaCi = OmegaC[i]
    OmegaGi = OmegaG0 * A[i]**-4.
    OmegaNi = OmegaN[i]

    # compute the derivatives of the perturbations.
    DPhi = -H[i]*Phi + (3/2.*A[i]**2/K) *\
        (4./3.*(OmegaGi*vG + OmegaN[i]*vN) + OmegaC[i]*vC + OmegaBi*vG)

    DdeltaG = -4./3.*K*vG + 4*DPhi
    DvG = (-H[i] * ybi*vG + K*deltaG/3)/(
        4./3. + ybi) + K*Phi
    
    DdeltaC =  -(1+wC[i])*(K*vC-3*DPhi) - 3*H[i]*(cs2C[i,:]-wC[i])*deltaC
    DvC = -H[i]*(1-3*wC[i])*vC - vC*DwC[i]/(1+wC[i]) + K*deltaC*cs2C[i,:]/(1+wC[i]) + K*Phi

    DdeltaN = -4./3.*K*vN + 4*DPhi
    DvN = K*deltaN/4 + K*Phi
    
    DdeltaN =  -(1+wN[i])*(K*vN-3*DPhi) - 3*H[i]*(cs2N[i,:]-wN[i])*deltaN
    DvN = -H[i]*(1-3*wN[i])*vN - vN*DwN[i]/(1+wN[i]) + K*deltaN*cs2N[i,:]/(1+wN[i]) + K*Phi

    dY = np.array([DPhi, DdeltaG, DvG, DdeltaC, DvC, DdeltaN, DvN])
    return dY

# %%
#@numba.njit
def solve_3fld_sk(A, K, wC, cs2C, wN, cs2N, OmegaB0, OmegaM0, OmegaN0, h):
    
    NT = len(A)
    
    # compute background after a0 using modified wC and wN.
    a_eq = 4.2e-5/(OmegaM0 * h**2)
    OmegaC0 = OmegaM0 - OmegaB0
    OmegaR0 = OmegaM0 * a_eq
    OmegaG0 = OmegaR0 - OmegaN0
    H =  H0 * A * np.sqrt(OmegaM0*A**-3 + OmegaR0*A**-4) 
    OmegaC = OmegaC0 * A**-3.
    OmegaN = OmegaN0 * A**-4.

    TAU = trapz(A, 1/(A * H))
    
    DwC = deriv(TAU, wC)
    DwN = deriv(TAU, wN)
                              
    y0 = A[0]/a_eq
    Phi0 = np.ones(len(K))
    deltaG0 = -2*Phi0*(1 + 3*y0/16)
    vG0 = -K/(H[0]) * (deltaG0/4 + (2*K**2 * (1 + y0)*Phi0) /
                              (9*(H[0])**2 * (4./3. + y0)))
    deltaC0 = .75 * deltaG0
    vC0 = vG0
    deltaN0 = deltaG0
    vN0 = vG0

    Y = np.zeros((NT//2, 7, len(K)))    
    Y[0, :, :] = np.array([Phi0, deltaG0, vG0, deltaC0, vC0, deltaN0, vN0])
    
    # Integrate using Runge-Kutta 4.
    for i in range(NT//2-1):
        ss = TAU[2*i+2] - TAU[2*i]
        k1 = ss*DY_3fld(2*i, Y[i, :, :], A, K, wC, DwC, cs2C, wN, DwN, cs2N,
            OmegaC, OmegaN, OmegaB0, OmegaC0, OmegaG0, OmegaN0, H)
        k2 = ss*DY_3fld(2*i+1, Y[i, :, :]+k1/2, A, K, wC, DwC, cs2C, wN, DwN, cs2N,
            OmegaC, OmegaN, OmegaB0, OmegaC0, OmegaG0, OmegaN0, H)
        k3 = ss*DY_3fld(2*i+1, Y[i, :, :]+k2/2, A, K, wC, DwC, cs2C, wN, DwN, cs2N,
            OmegaC, OmegaN, OmegaB0, OmegaC0, OmegaG0, OmegaN0, H)
        k4 = ss*DY_3fld(2*i+2, Y[i, :, :]+k3, A, K, wC, DwC, cs2C, wN, DwN, cs2N,
            OmegaC, OmegaN, OmegaB0, OmegaC0, OmegaG0, OmegaN0, H)
        Y[i+1, :, :] = Y[i, :, :] + k1/6 + k2/3 + k3/3 + k4/6
    return Y

# %%
NK = 1000
NT = 1000

A = np.append(
    np.linspace(a0, a_rec/10, NT//2),
    np.linspace(a_rec/10, a_rec, NT//2+1)[1:]
)
A = np.linspace(a0, a_rec, NT)
K = np.linspace(.1, 3000, NK)
bump = np.exp(-(A - 5.e-4)**2 /(2*1.e-4**2))

# seljak free params
h = .5
H0 = 1.
OmegaB0 = 0.05
OmegaM0 = 1.0
OmegaN0 = 0.
wC = np.zeros(NT)#+ bump
wN = np.ones(NT)*1/3
cs2C = np.zeros((NT, NK))
cs2N = np.ones((NT, NK))*1/3

Y = solve_3fld_sk(A, K, wC, cs2C, wN, cs2N, OmegaB0, OmegaM0, OmegaN0, h)

# %%
plt.plot(A[::2],Y[:,0,::20])
#plt.plot(Y[:,0,::20])
plt.show()

# %%
#k/H0
#k tau_r
#= 2* (a_rec/Omega_m)^1/2 k / H0

fig, ax = plt.subplots(figsize=(10, 5))

img = plt.imread("img/seljak_1.png")
ax.imshow(img, extent=[-1, 2.2, -1.5, 1.5],aspect='auto')
plt.xlim(-1,2.2)
plt.ylim(-1.5,1.5)
#xs*K/tau_r
tau_s = 0.6 * OmegaM0**.25 * OmegaB0**-.5 * a_rec**.75 * h**-.5 / tau_r
sigma = 0.03
damp = np.exp(-K**2 * tau_s**2)
tau_rec = x_rec/tau_r
#damp =  np.exp(-K**2 * (tau_s**2 + sigma**2*tau_rec**2))
DOP = Y[-1,2,:]
SW = Y[-1,0,:] + Y[-1,1,:]/4
plt.plot(np.log10(K/tau_r),-DOP*damp)
plt.plot(np.log10(K/tau_r),-SW*damp)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
N_BESSEL = 10000
L_MAX = 2500
x_bessel_low = 0.01
x_bessel_high = 3000


# list of points where bessels are evaluated
x_bessel = np.linspace(x_bessel_low, x_bessel_high, N_BESSEL)

# Set the list of l values for C_l.
L = np.array([i for i in range(2, 50, 1)]+[i for i in range(50, 200, 5)] +
                  [i for i in range(200, L_MAX, 20)])
#k_grid = np.broadcast_to(K_INT, (len(l_list), N_BESSEL))

def get_bessels():
    # try to load bessel functions from file:
    try:
        JLK = pickle.load(open("output/bessel_JLK.p", "rb"))
        DJLK = pickle.load(open("output/bessel_DJLK.p", "rb"))
        print('Bessel functions loaded from file.')
    except:
        print("Bessel functions not found. Computing bessel functions...\n")
        JLK = np.array([
            spherical_jn(l, x_bessel)
            for l in L])
        DJLK = np.array([
            spherical_jn(l, x_bessel, derivative=True)
            for l in L])
        pickle.dump(JLK, open("output/bessel_JLK.p", "wb"))
        pickle.dump(DJLK, open("output/bessel_DJLK.p", "wb"))
        print('Bessel functions stored.')
    return JLK, DJLK
JLK, DJLK = get_bessels()
# Out:
# Bessel functions not found. Computing bessel functions...
#
# Bessel functions stored.
